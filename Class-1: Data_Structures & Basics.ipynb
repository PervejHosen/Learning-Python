# %% [markdown]
# <a href="https://colab.research.google.com/github/PervejHosen/Learning-Python/blob/main/Python_Data_Structures_and_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Code Snippet

# %% [markdown]
# **A Snippet of Python Codes to make a Visualization**

# %%
#The code cell below uses numpy to generate some random data, and uses matplotlib to visualise it
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
print(len(ys))
len(ys)
# Out:
# 100
# 100

# %%
#Type of Data in Python

# %% [markdown]
# # **Type of Data/Variable in Python**

# %% [markdown]
# **Types**: Numbers, Strings, Boolean, Lists, Dictionaries, Tuples, Sets

# %% [markdown]
# ##**Numbers:**
# Python has two main types of numbers- int [integers] & float [floating point numbers or decimals]

# %%
print(type(1)) # int
print(type(-10)) # int
print(type(0)) # int
print(type(0.0)) # float
print(type(2.2)) # float
print(type(4E2)) # float - 4*10 to the power of 2
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# Arithmetic
print(10 + 3) # 13
print(10 - 3) # 7
print(10 * 3) # 30
print(10 ** 3) # 1000
print(10 / 3) # 3.3333333333333335
print(10 // 3) # 3 --> floor division - no decimals and returns an int
print(10 % 3) # 1 --> modulo operator - return the reminder. Good for deciding if number is even or odd
# Out:
# 13
# 7
# 30
# 1000
# 3.3333333333333335
# 3
# 1

# %%
# Basic Functions
pow(5, 2) # 25 --> like doing 5**2
abs(-50) # 50
round(5.46) # 5
round(5.468, 2)# 5.47 --> round to nth digit
# Out:
# 5.47

# %%
age = input("How old are you?")
# Out:
# How old are you?32

# %%
type(age)
# Out:
# str

# %%
age = int(age)
type(age)
# Out:
# int

# %% [markdown]
# ##**Strings:**
# Strings in python are stored as sequences of letters in memory.

# %%
print(len("Shabbir Hossain"))
type("Shabbir Hossain")
# Out:
# 15
# str

# %%
name = 'Shabbir Hossain'
name[3]
# Out:
# 'b'

# %% [markdown]
#  **For 3, returning the fourth letter; So, Python is Zero Indexed;
# Also, For String, both single and double quotation workds.
# Strings in python are stored as sequences of letters in memory.**

# %%
print(name[1:])
print(name[:1])
print(name[::-1])

name[0:10:2] #: is called slicing and has the format [ start : end : step ]
# Out:
# habbir Hossain
# S
# niassoH ribbahS
# 'SabrH'

# %%
'Hi there ' + 'Rossi' # 'Hi there Rossi' --> This is called string concatenation
# Out:
# 'Hi there Rossi'

# %%
' I am alone '.strip() #Strips all whitespace
# Out:
# 'I am alone'

# %%
'ok, I am done.'.capitalize()
# Out:
# 'Ok, i am done.'

# %%
'On an island'.strip('d')
# Out:
# 'On an islan'

# %%
'Help me'.replace('me', 'you')
# Out:
# 'Help you'

# %%
'but life is good!'.split()
# Out:
# ['but', 'life', 'is', 'good!']

# %%
'oh hi there'.find('i')
# Out:
# 4

# %%
# String Formatting
name1 = 'Paolo'
name2 = 'Rossi'
print(f'Hello there {name1} {name2}')
# Out:
# Hello there Paolo Rossi

# %% [markdown]
# ##**Boolean**:
# True or False. Used in a lot of comparison and logical operations in Python.

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
# all of the below evaluate to False. Everything else will evaluate to True in Python.
print(bool(None))
print(bool(False))
print(bool(0))
print(bool(0.0))
print(bool([]))
print(bool({}))
print(bool(()))
print(bool(''))
print(bool(range(0)))
print(bool(set()))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ##**Lists**:
# Unlike strings, lists are mutable sequences in python.

# %%
my_list = [1, 2, '3', True]# We assume this list won't mutate for each example below
len(my_list) #4
my_list.index('3') #2
my_list.count(2) # 1 --> count how many times 2 appears
my_list[3] # True
my_list[1:] # [2, '3', True]
my_list[:1] # [1]
my_list[-1] # True
my_list[::1] # [1, 2, '3', True]
my_list[::-1] # [True, '3', 2, 1]
my_list[0:3:2] # [1, '3']

# : is called slicing and has the format [ start : end : step ]
# Out:
# [1, '3']

# %%
# Add to List
my_list * 2
# Out:
# [1, 2, '3', True, 1, 2, '3', True]

# %%
my_list + [100] # [1, 2, '3', True, 100] --> doesn't mutate original list, creates new one
# Out:
# [1, 2, '3', True, 100]

# %%
my_list.append(100) #Mutate original list
print(my_list)
# Out:
# [1, 2, '3', True, 100, 100]

# %%
my_list.extend([100, 200])
print(my_list)

# %%
my_list.insert(2, '!!!')  #[1,2,'!!!', '3', True] --> Inserts item at index and moves the rest to the right

# %%
' '.join(['Hello','There']) #Joins elements using string as separator
# Out:
# 'Hello  There'

# %%
# Copy a List
basket = ['apples', 'pears', 'oranges']
new_basket = basket.copy()
print(new_basket)
# Out:
# ['apples', 'pears', 'oranges']

# %%
x = [1,2,3]
x.clear()
print(x)
# Out:
# []

# %%
# Ordering
x = [1,2,5,3]
x.sort()
print(x)
# Out:
# [1, 2, 3, 5]

# %%
[1,2,5,3].sort(reverse=True)

# %%
[1,2,5,3].reverse()

# %%
sorted([1,2,5,3])        # [1, 2, 3, 5] --> new list created
# Out:
# [1, 2, 3, 5]

# %%
# Useful operations
print(1 in [1,2,5,3])  # True
print(min([1,2,3,4,5]))# 1
print(max([1,2,3,4,5]))# 5
sum([1,2,3,4,5])# 15
# Out:
# True
# 1
# 5
# 15

# %%
# Get First and Last element of a list
mList = [63, 21, 30, 14, 35, 26, 77, 18, 49, 10]
first, *x, last = mList
print(first) #63
print(last) #10
# Out:
# 63
# 10

# %% [markdown]
# ##**Dictionaries**:
# Also known as mappings or hash tables. They are key value pairs that are guaranteed to retain order of insertion

# %%
my_dict = {
    'name': 'Andrei',
    'age': 30,
    'magic_power': False}
print(my_dict)
# Out:
# {'name': 'Andrei Neagoie', 'age': 30, 'magic_power': False}

# %%
my_dict1 = {
    'name': ['Andrei',  'Rossi', 'Paolo'],
    'age': [30, 32, 24],
    'magic_power': [False, True, True]}
print(my_dict1)
# Out:
# {'name': ['Andrei', 'Rossi', 'Paolo'], 'age': [30, 32, 24], 'magic_power': [False, True, True]}

# %%
my_dict1['name']
# Out:
# ['Andrei', 'Rossi', 'Paolo']

# %%
len(my_dict1)
# Out:
# 3

# %%
list(my_dict.keys())
# Out:
# ['name', 'age', 'magic_power']

# %%
list(my_dict.values())
# Out:
# ['Andrei Neagoie', 30, False]

# %%
list(my_dict1.keys())
# Out:
# ['name', 'age', 'magic_power']

# %%
list(my_dict1.values())
# Out:
# [['Andrei', 'Rossi', 'Paolo'], [30, 32, 24], [False, True, True]]

# %%
list(my_dict.items())
# Out:
# [('name', 'Andrei Neagoie'), ('age', 30), ('magic_power', False)]

# %%
list(my_dict1.items())
# Out:
# [('name', ['Andrei', 'Rossi', 'Paolo']),
#  ('age', [30, 32, 24]),
#  ('magic_power', [False, True, True])]

# %%
my_dict.get('age')
# Out:
# 30

# %%
my_dict1.get('age')
# Out:
# [30, 32, 24]

# %%
my_dict.get('ages', 0 ) ## 0 --> Returns default (2nd param) if key is not found
# Out:
# 0

# %%
#Remove key
del my_dict['name']

# %%
print(my_dict)
# Out:
# {'age': 30, 'magic_power': False}

# %%
my_dict.update({'cool': True})
print(my_dict)
# Out:
# {'age': 30, 'magic_power': False, 'cool': True}

# %%
new_dict = dict(zip(['name','age','magic_power'],['Andrei',32, False]))# Creates a dict from two collections
new_dict
# Out:
# {'name': 'Andrei', 'age': 32, 'magic_power': False}

# %% [markdown]
# ##**Tuples**:
# Like lists, but they are used for immutable things (that don't change).

# %%
my_tuple = ('apple','grapes','mango', 'grapes')

# %%
len(my_tuple) # 4
my_tuple[2] #mango
#my_tuple[-1] #
# Out:
# 'mango'

# %%
# Immutability
my_tuple[1] = 'donuts'  # TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-ab95d765df66> in <cell line: 2>()
#       1 # Immutability
# ----> 2 my_tuple[1] = 'donuts'  # TypeError
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple.append('candy')# AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-af1dcbeb0b7b> in <cell line: 1>()
# ----> 1 my_tuple.append('candy')# AttributeError
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Methods
my_tuple.index('grapes') # 1
# Out:
# 1

# %%
# Methods
my_tuple.count('grapes') # 2
# Out:
# 2

# %%
# Zip
list(zip([1,2,3], [4,5,6])) # [(1, 4), (2, 5), (3, 6)]
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
# unzip
z = [(1, 2), (3, 4), (5, 6), (7, 8)] # Some output of zip() function
unzip = lambda z: list(zip(*z))
unzip(z)
# Out:
# [(1, 3, 5, 7), (2, 4, 6, 8)]

# %% [markdown]
# ##**Sets**:
# Unordered collection of unique elements. *** No Duplicates

# %%
my_set = set()
my_set.add(1)  # {1}
my_set.add(100)# {1, 100}
my_set.add(100)# {1, 100} --> no duplicates!
print(my_set)
# Out:
# {1, 100}

# %%
new_list = [1,2,3,3,3,4,4,5,6,1]
set(new_list)
# {1, 2, 3, 4, 5, 6}
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.remove(100) #Raises KeyError if element not found

# %%
my_set.discard(100) #Doesn't Raise KeyError if element not found

# %%
my_set.clear()

# %%
set1 = {1,2,3}
set2 = {3,4,8}
set3 = set1.union(set2)
print(set3)
set4 = set1.intersection(set2)
print(set4)
# Out:
# {1, 2, 3, 4, 8}
# {3}

# %% [markdown]
# ##**None**:
# None is used for absence of a value and can be used to show nothing has been assigned to an object.

# %%
type (None)
# Out:
# NoneType

# %%
a = None

# %% [markdown]
# #COMPARISON OPERATORS:

# %%
# ==                   # equal values
# !=                   # not equal
# >                    # left operand is greater than right operand
# <                    # left operand is less than right operand
# >=                   # left operand is greater than or equal to right operand
# <=                   # left operand is less than or equal to right operand

# %% [markdown]
# #LOGICAL OPERATORS:

# %%
1 < 2 and 4 > 1
#1>3or4>1
#1 is not 4
#not True
#1 not in [2,3,4]
# Out:
# True

# %% [markdown]
# if <condition that evaluates to boolean>:
#   # perform action1
# elif <condition that evaluates to boolean>:
#   # perform action2
# else:
#   # perform action3

# %% [markdown]
# #Range:

# %%
range(10)          # range(0, 10) --> 0 to 9
range(1,10)        # range(1, 10)
list(range(0,10,2))# [0, 2, 4, 6, 8]
# Out:
# [0, 2, 4, 6, 8]
